# %%
"""
데이터셋
Crema, Ravdess, Tess, Savee

Positive: happiness - 2323
Neutral: neutral, calmness - 1895
Negative: anger, sadness - 3846
"""

# %%
import numpy as np
import time
from tqdm import tqdm
import os
import librosa
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from keras.utils.np_utils import to_categorical
from keras.models import load_model, Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, BatchNormalization, Dense, Dropout
# Out:
# C:\Users\DeepLearning_5\Anaconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.24.3) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
base_dir = 'dataset'

n_mfcc = 128
num_features = 153
input_shape = (num_features, 1)

n_epochs = 150
batch_size = None
split_val = True

model_save_path = 'saved_models/model.h5'

# %%
def load_feature_tuple(file_name):
    y, sr = librosa.load(file_name, mono=True)

    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    
    spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sr)
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
    spectral_flatness = librosa.feature.spectral_flatness(y=y)
    spectral_rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    
    zero_crossing_rate = librosa.feature.zero_crossing_rate(y=y)
    
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    
    rms = librosa.feature.rms(y=y)
    
    
    image = []
    
    for row in mfcc:
        image.append(np.mean(row))
    
    image.append(np.mean(spectral_centroid))
    image.append(np.mean(spectral_bandwidth))
    for row in spectral_contrast:
        image.append(np.mean(row))
    image.append(np.mean(spectral_flatness))
    image.append(np.mean(spectral_rolloff))
    
    image.append(np.mean(zero_crossing_rate))
    for row in chroma_stft:
        image.append(np.mean(row))
    image.append(np.mean(rms))
    
    return np.array(image)

# %%
def extract_feature(file_name):
    return load_feature_tuple(file_name)

# %%
def fetch_dataset(dir_path, label):
    _features = np.empty((0, ) + input_shape)
    for file_name in tqdm(os.listdir(dir_path)):
        file_path = os.path.join(dir_path, file_name)
        feature = extract_feature(file_path).reshape((1, ) + input_shape)
        _features = np.append(_features, feature, axis=0)

    _labels = np.full((_features.shape[0], ), label)

    return _features, _labels

# %% [markdown]
# # 데이터셋 가져오기

# %%
start_time = time.time()

positive_features, positive_labels = fetch_dataset(base_dir + '/positive', 'POSITIVE')
neutral_features, neutral_labels = fetch_dataset(base_dir + '/neutral', 'NEUTRAL')
negative_features, negative_labels = fetch_dataset(base_dir + '/negative', 'NEGATIVE')

print('elapsed time fetching dataset (sec):', time.time() - start_time)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2323/2323 [04:08<00:00,  9.36it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1895/1895 [04:23<00:00,  7.20it/s]
#  65%|██████████████████████████████████████████████████▋                           | 2497/3846 [05:15<02:01, 11.06it/s]C:\Users\DeepLearning_5\Anaconda3\lib\site-packages\librosa\core\pitch.py:153: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn("Trying to estimate tuning from empty frequency set.")
# 100%|██████████████████████████████████████████████████████████████████████████████| 3846/3846 [07:36<00:00,  8.43it/s]
# elapsed time fetching dataset (sec): 967.6094632148743

# %%
features = np.concatenate((positive_features, neutral_features, negative_features), axis=0)
labels = np.concatenate((positive_labels, neutral_labels, negative_labels), axis=0)

print('features shape:', features.shape)
print('labels shape before encoding:', labels.shape)
# Out:
# features shape: (8064, 153, 1)
# labels shape before encoding: (8064,)

# %%
le = LabelEncoder()
labels = to_categorical(le.fit_transform(labels))
print('labels shape after encoding:', labels.shape)
print('label encoder classes:', le.classes_)
# Out:
# labels shape after encoding: (8064, 3)
# label encoder classes: ['NEGATIVE' 'NEUTRAL' 'POSITIVE']

# %%
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.2)

# %% [markdown]
# # 학습

# %%
model = Sequential()

# Block 1
model.add(Conv1D(64, 3, activation='relu', padding='same', name='block1_conv1', input_shape=input_shape))
model.add(Conv1D(64, 3, activation='relu', padding='same', name='block1_conv2'))
model.add(MaxPooling1D(2, strides=2, name='block1_pool'))

# Block 2
model.add(Conv1D(128, 3, activation='relu', padding='same', name='block2_conv1'))
model.add(Conv1D(128, 3, activation='relu', padding='same', name='block2_conv2'))
model.add(MaxPooling1D(2, strides=2, name='block2_pool'))

# Block 3
model.add(Conv1D(256, 3, activation='relu', padding='same', name='block3_conv1'))
model.add(Conv1D(256, 3, activation='relu', padding='same', name='block3_conv2'))
model.add(Conv1D(256, 3, activation='relu', padding='same', name='block3_conv3'))
model.add(MaxPooling1D(2, strides=2, name='block3_pool'))

# Block 4
model.add(Conv1D(512, 3, activation='relu', padding='same', name='block4_conv1'))
model.add(Conv1D(512, 3, activation='relu', padding='same', name='block4_conv2'))
model.add(Conv1D(512, 3, activation='relu', padding='same', name='block4_conv3'))
model.add(MaxPooling1D(2, strides=2, name='block4_pool'))

# Block 5
model.add(Conv1D(512, 3, activation='relu', padding='same', name='block5_conv1'))
model.add(Conv1D(512, 3, activation='relu', padding='same', name='block5_conv2'))
model.add(Conv1D(512, 3, activation='relu', padding='same', name='block5_conv3'))
model.add(MaxPooling1D(2, strides=2, name='block5_pool'))

model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv1D)       (None, 153, 64)           256
#
#  block1_conv2 (Conv1D)       (None, 153, 64)           12352
#
#  block1_pool (MaxPooling1D)  (None, 76, 64)            0
#
#  block2_conv1 (Conv1D)       (None, 76, 128)           24704
#
#  block2_conv2 (Conv1D)       (None, 76, 128)           49280
#
#  block2_pool (MaxPooling1D)  (None, 38, 128)           0
#
#  block3_conv1 (Conv1D)       (None, 38, 256)           98560
#
#  block3_conv2 (Conv1D)       (None, 38, 256)           196864
#
#  block3_conv3 (Conv1D)       (None, 38, 256)           196864
#
#  block3_pool (MaxPooling1D)  (None, 19, 256)           0
#
#  block4_conv1 (Conv1D)       (None, 19, 512)           393728
#
#  block4_conv2 (Conv1D)       (None, 19, 512)           786944
#
#  block4_conv3 (Conv1D)       (None, 19, 512)           786944
#
#  block4_pool (MaxPooling1D)  (None, 9, 512)            0
#
#  block5_conv1 (Conv1D)       (None, 9, 512)            786944
#
#  block5_conv2 (Conv1D)       (None, 9, 512)            786944
#
#  block5_conv3 (Conv1D)       (None, 9, 512)            786944
#
#  block5_pool (MaxPooling1D)  (None, 4, 512)            0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  batch_normalization (BatchN  (None, 2048)             8192
#  ormalization)
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 3)                 3075
#
# =================================================================
# Total params: 7,016,771
# Trainable params: 7,012,675
# Non-trainable params: 4,096
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
if split_val:
    validation_split = 0.25
else:
    validation_split = 0.0

# %%
start_time = time.time()

hist = model.fit(x_train, y_train,
                 epochs=n_epochs,
                 batch_size=batch_size,
                 validation_split=validation_split,
                 shuffle=True,
                 verbose=1)

print('elapsed time training dataset (sec):', time.time() - start_time)

model.save(model_save_path)
# Out:
# Epoch 1/150
# 152/152 [==============================] - 9s 24ms/step - loss: 1.9904 - accuracy: 0.4661 - val_loss: 22.8569 - val_accuracy: 0.4706
# Epoch 2/150
# 152/152 [==============================] - 3s 19ms/step - loss: 1.2999 - accuracy: 0.5234 - val_loss: 39.4249 - val_accuracy: 0.2405
# Epoch 3/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.9656 - accuracy: 0.5595 - val_loss: 7.1609 - val_accuracy: 0.2647
# Epoch 4/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.8458 - accuracy: 0.5994 - val_loss: 34.0620 - val_accuracy: 0.2895
# Epoch 5/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.8028 - accuracy: 0.6104 - val_loss: 122.4332 - val_accuracy: 0.5877
# Epoch 6/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.7348 - accuracy: 0.6377 - val_loss: 145.1364 - val_accuracy: 0.5908
# Epoch 7/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.7200 - accuracy: 0.6573 - val_loss: 107.3703 - val_accuracy: 0.5282
# Epoch 8/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.6992 - accuracy: 0.6521 - val_loss: 218.5695 - val_accuracy: 0.5102
# Epoch 9/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.7008 - accuracy: 0.6461 - val_loss: 355.4377 - val_accuracy: 0.5387
# Epoch 10/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.6966 - accuracy: 0.6621 - val_loss: 1.4856 - val_accuracy: 0.5741
# Epoch 11/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.6938 - accuracy: 0.6530 - val_loss: 0.7257 - val_accuracy: 0.6404
# Epoch 12/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.6805 - accuracy: 0.6618 - val_loss: 0.8923 - val_accuracy: 0.5759
# Epoch 13/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.6848 - accuracy: 0.6596 - val_loss: 3.0200 - val_accuracy: 0.5666
# Epoch 14/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.6667 - accuracy: 0.6761 - val_loss: 0.9987 - val_accuracy: 0.5859
# Epoch 15/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.6688 - accuracy: 0.6616 - val_loss: 94.5841 - val_accuracy: 0.5226
# Epoch 16/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.6737 - accuracy: 0.6629 - val_loss: 1.6019 - val_accuracy: 0.5611
# Epoch 17/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.6627 - accuracy: 0.6716 - val_loss: 11.9663 - val_accuracy: 0.5536
# Epoch 18/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.6738 - accuracy: 0.6621 - val_loss: 18.7596 - val_accuracy: 0.4185
# Epoch 19/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.6649 - accuracy: 0.6767 - val_loss: 492.4036 - val_accuracy: 0.6026
# Epoch 20/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.6455 - accuracy: 0.6788 - val_loss: 126.2986 - val_accuracy: 0.5871
# Epoch 21/150
# 152/152 [==============================] - 4s 24ms/step - loss: 0.6311 - accuracy: 0.6947 - val_loss: 1.5215 - val_accuracy: 0.4774
# Epoch 22/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.6453 - accuracy: 0.6780 - val_loss: 2.0512 - val_accuracy: 0.6051
# Epoch 23/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.6227 - accuracy: 0.6918 - val_loss: 0.7585 - val_accuracy: 0.6249
# Epoch 24/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.6409 - accuracy: 0.6908 - val_loss: 1.5472 - val_accuracy: 0.5511
# Epoch 25/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.6166 - accuracy: 0.6990 - val_loss: 0.9794 - val_accuracy: 0.6051
# Epoch 26/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.6237 - accuracy: 0.6982 - val_loss: 2160.2559 - val_accuracy: 0.6727
# Epoch 27/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.6593 - accuracy: 0.6846 - val_loss: 4.2142 - val_accuracy: 0.5859
# Epoch 28/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.6168 - accuracy: 0.6968 - val_loss: 1.7527 - val_accuracy: 0.5797
# Epoch 29/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.6192 - accuracy: 0.7055 - val_loss: 1.3567 - val_accuracy: 0.5437
# Epoch 30/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.6082 - accuracy: 0.7098 - val_loss: 9.9378 - val_accuracy: 0.5840
# Epoch 31/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.5937 - accuracy: 0.7044 - val_loss: 3.4968 - val_accuracy: 0.6125
# Epoch 32/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.5943 - accuracy: 0.7112 - val_loss: 0.8109 - val_accuracy: 0.6435
# Epoch 33/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.5789 - accuracy: 0.7232 - val_loss: 666.2247 - val_accuracy: 0.5586
# Epoch 34/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.5844 - accuracy: 0.7125 - val_loss: 1.6477 - val_accuracy: 0.5542
# Epoch 35/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.5679 - accuracy: 0.7348 - val_loss: 1.2504 - val_accuracy: 0.6448
# Epoch 36/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.5484 - accuracy: 0.7414 - val_loss: 0.6906 - val_accuracy: 0.6931
# Epoch 37/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.5516 - accuracy: 0.7379 - val_loss: 1.5596 - val_accuracy: 0.6113
# Epoch 38/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.5251 - accuracy: 0.7503 - val_loss: 1.0953 - val_accuracy: 0.6522
# Epoch 39/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.5540 - accuracy: 0.7416 - val_loss: 1.6714 - val_accuracy: 0.5846
# Epoch 40/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.5133 - accuracy: 0.7648 - val_loss: 0.9715 - val_accuracy: 0.6367
# Epoch 41/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.5079 - accuracy: 0.7662 - val_loss: 0.9026 - val_accuracy: 0.6764
# Epoch 42/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.5000 - accuracy: 0.7646 - val_loss: 1.0534 - val_accuracy: 0.6565
# Epoch 43/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.4868 - accuracy: 0.7741 - val_loss: 2.4592 - val_accuracy: 0.6094
# Epoch 44/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.5051 - accuracy: 0.7677 - val_loss: 1.0345 - val_accuracy: 0.6776
# Epoch 45/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.4706 - accuracy: 0.7788 - val_loss: 2.8272 - val_accuracy: 0.5716
# Epoch 46/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.4576 - accuracy: 0.7964 - val_loss: 651.6199 - val_accuracy: 0.6342
# Epoch 47/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.4249 - accuracy: 0.8007 - val_loss: 0.8654 - val_accuracy: 0.6615
# Epoch 48/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.4473 - accuracy: 0.7906 - val_loss: 1.4093 - val_accuracy: 0.6051
# Epoch 49/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.4056 - accuracy: 0.8191 - val_loss: 0.8267 - val_accuracy: 0.6894
# Epoch 50/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.4038 - accuracy: 0.8187 - val_loss: 1.8315 - val_accuracy: 0.5970
# Epoch 51/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.3918 - accuracy: 0.8280 - val_loss: 1.2511 - val_accuracy: 0.6317
# Epoch 52/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.3838 - accuracy: 0.8322 - val_loss: 17.0452 - val_accuracy: 0.6417
# Epoch 53/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.3869 - accuracy: 0.8388 - val_loss: 3.5034 - val_accuracy: 0.6466
# Epoch 54/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.3434 - accuracy: 0.8535 - val_loss: 1.0521 - val_accuracy: 0.6702
# Epoch 55/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.3333 - accuracy: 0.8557 - val_loss: 7.6361 - val_accuracy: 0.5294
# Epoch 56/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.3504 - accuracy: 0.8504 - val_loss: 2.4557 - val_accuracy: 0.6162
# Epoch 57/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.3476 - accuracy: 0.8485 - val_loss: 1.9539 - val_accuracy: 0.6212
# Epoch 58/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.3292 - accuracy: 0.8634 - val_loss: 1.7860 - val_accuracy: 0.6565
# Epoch 59/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.3225 - accuracy: 0.8634 - val_loss: 2.9179 - val_accuracy: 0.6175
# Epoch 60/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.4797 - accuracy: 0.7983 - val_loss: 3.4680 - val_accuracy: 0.6274
# Epoch 61/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.2879 - accuracy: 0.8764 - val_loss: 4.5361 - val_accuracy: 0.6603
# Epoch 62/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.2533 - accuracy: 0.8973 - val_loss: 1.2563 - val_accuracy: 0.6906
# Epoch 63/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.2782 - accuracy: 0.8871 - val_loss: 12.2023 - val_accuracy: 0.6727
# Epoch 64/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.2425 - accuracy: 0.9043 - val_loss: 1.1495 - val_accuracy: 0.6950
# Epoch 65/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.2200 - accuracy: 0.9150 - val_loss: 85543.0938 - val_accuracy: 0.6330
# Epoch 66/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.2450 - accuracy: 0.9045 - val_loss: 1.8476 - val_accuracy: 0.6417
# Epoch 67/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.2450 - accuracy: 0.9014 - val_loss: 8139.6768 - val_accuracy: 0.6652
# Epoch 68/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.2644 - accuracy: 0.9000 - val_loss: 1.7420 - val_accuracy: 0.6900
# Epoch 69/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.1925 - accuracy: 0.9241 - val_loss: 2.1154 - val_accuracy: 0.6603
# Epoch 70/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.1845 - accuracy: 0.9326 - val_loss: 1.5657 - val_accuracy: 0.6764
# Epoch 71/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.1905 - accuracy: 0.9279 - val_loss: 79564.1719 - val_accuracy: 0.6609
# Epoch 72/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.1498 - accuracy: 0.9432 - val_loss: 106.0466 - val_accuracy: 0.6987
# Epoch 73/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.1685 - accuracy: 0.9405 - val_loss: 2.3573 - val_accuracy: 0.6795
# Epoch 74/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.1872 - accuracy: 0.9305 - val_loss: 3.7122 - val_accuracy: 0.5797
# Epoch 75/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.1558 - accuracy: 0.9450 - val_loss: 4.1655 - val_accuracy: 0.7043
# Epoch 76/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.1281 - accuracy: 0.9562 - val_loss: 1.8535 - val_accuracy: 0.6658
# Epoch 77/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.1246 - accuracy: 0.9574 - val_loss: 5.0919 - val_accuracy: 0.6472
# Epoch 78/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.1830 - accuracy: 0.9353 - val_loss: 25.2309 - val_accuracy: 0.5846
# Epoch 79/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.1584 - accuracy: 0.9372 - val_loss: 1.8452 - val_accuracy: 0.6956
# Epoch 80/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.1187 - accuracy: 0.9578 - val_loss: 119.9618 - val_accuracy: 0.6863
# Epoch 81/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.1169 - accuracy: 0.9585 - val_loss: 1.7390 - val_accuracy: 0.6615
# Epoch 82/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.1150 - accuracy: 0.9605 - val_loss: 1.7860 - val_accuracy: 0.6578
# Epoch 83/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0847 - accuracy: 0.9725 - val_loss: 1.8781 - val_accuracy: 0.6875
# Epoch 84/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.1345 - accuracy: 0.9564 - val_loss: 2.7041 - val_accuracy: 0.6330
# Epoch 85/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0916 - accuracy: 0.9663 - val_loss: 2.8709 - val_accuracy: 0.6379
# Epoch 86/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0737 - accuracy: 0.9752 - val_loss: 2.5638 - val_accuracy: 0.6813
# Epoch 87/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0959 - accuracy: 0.9667 - val_loss: 2.8136 - val_accuracy: 0.6708
# Epoch 88/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.1874 - accuracy: 0.9423 - val_loss: 1085.5519 - val_accuracy: 0.6826
# Epoch 89/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0908 - accuracy: 0.9711 - val_loss: 57.4655 - val_accuracy: 0.7018
# Epoch 90/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0904 - accuracy: 0.9721 - val_loss: 29.9259 - val_accuracy: 0.6237
# Epoch 91/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0698 - accuracy: 0.9756 - val_loss: 2.3337 - val_accuracy: 0.6838
# Epoch 92/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0675 - accuracy: 0.9789 - val_loss: 357.0375 - val_accuracy: 0.6702
# Epoch 93/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0933 - accuracy: 0.9661 - val_loss: 2.3435 - val_accuracy: 0.6869
# Epoch 94/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0717 - accuracy: 0.9783 - val_loss: 2.8810 - val_accuracy: 0.6565
# Epoch 95/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0949 - accuracy: 0.9700 - val_loss: 3.4063 - val_accuracy: 0.6807
# Epoch 96/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0732 - accuracy: 0.9789 - val_loss: 4.3839 - val_accuracy: 0.6764
# Epoch 97/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0686 - accuracy: 0.9781 - val_loss: 2.1767 - val_accuracy: 0.6882
# Epoch 98/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.1063 - accuracy: 0.9636 - val_loss: 2.7023 - val_accuracy: 0.6869
# Epoch 99/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0861 - accuracy: 0.9725 - val_loss: 2.0748 - val_accuracy: 0.6665
# Epoch 100/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0981 - accuracy: 0.9713 - val_loss: 225.7052 - val_accuracy: 0.7006
# Epoch 101/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0631 - accuracy: 0.9783 - val_loss: 1330.4504 - val_accuracy: 0.6820
# Epoch 102/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0493 - accuracy: 0.9851 - val_loss: 3151.4573 - val_accuracy: 0.6584
# Epoch 103/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0677 - accuracy: 0.9806 - val_loss: 2.4895 - val_accuracy: 0.6813
# Epoch 104/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0419 - accuracy: 0.9857 - val_loss: 2.3312 - val_accuracy: 0.6875
# Epoch 105/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0946 - accuracy: 0.9684 - val_loss: 7206.2007 - val_accuracy: 0.6968
# Epoch 106/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0605 - accuracy: 0.9797 - val_loss: 975.5922 - val_accuracy: 0.6609
# Epoch 107/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0523 - accuracy: 0.9837 - val_loss: 4.4882 - val_accuracy: 0.6572
# Epoch 108/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0565 - accuracy: 0.9791 - val_loss: 2.9284 - val_accuracy: 0.6919
# Epoch 109/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0343 - accuracy: 0.9888 - val_loss: 2.7121 - val_accuracy: 0.6838
# Epoch 110/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0868 - accuracy: 0.9727 - val_loss: 2.9917 - val_accuracy: 0.6658
# Epoch 111/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.1042 - accuracy: 0.9690 - val_loss: 2.0788 - val_accuracy: 0.6894
# Epoch 112/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0833 - accuracy: 0.9709 - val_loss: 2.8817 - val_accuracy: 0.6640
# Epoch 113/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0688 - accuracy: 0.9783 - val_loss: 2.3398 - val_accuracy: 0.6956
# Epoch 114/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0560 - accuracy: 0.9822 - val_loss: 2.6473 - val_accuracy: 0.6745
# Epoch 115/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0321 - accuracy: 0.9880 - val_loss: 2.9803 - val_accuracy: 0.6851
# Epoch 116/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0446 - accuracy: 0.9882 - val_loss: 2.3041 - val_accuracy: 0.6782
# Epoch 117/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0585 - accuracy: 0.9833 - val_loss: 2.4118 - val_accuracy: 0.6708
# Epoch 118/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0617 - accuracy: 0.9797 - val_loss: 2.4960 - val_accuracy: 0.6646
# Epoch 119/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0572 - accuracy: 0.9837 - val_loss: 2.3606 - val_accuracy: 0.6987
# Epoch 120/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0536 - accuracy: 0.9833 - val_loss: 2.5702 - val_accuracy: 0.6708
# Epoch 121/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0697 - accuracy: 0.9783 - val_loss: 2.2278 - val_accuracy: 0.6615
# Epoch 122/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0337 - accuracy: 0.9880 - val_loss: 4.1183 - val_accuracy: 0.6627
# Epoch 123/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0663 - accuracy: 0.9800 - val_loss: 2.2081 - val_accuracy: 0.6987
# Epoch 124/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0268 - accuracy: 0.9913 - val_loss: 372.1323 - val_accuracy: 0.6801
# Epoch 125/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0612 - accuracy: 0.9810 - val_loss: 2.4709 - val_accuracy: 0.6764
# Epoch 126/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0313 - accuracy: 0.9915 - val_loss: 2.7515 - val_accuracy: 0.6826
# Epoch 127/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0578 - accuracy: 0.9816 - val_loss: 2.8716 - val_accuracy: 0.6634
# Epoch 128/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0551 - accuracy: 0.9824 - val_loss: 2.6554 - val_accuracy: 0.6708
# Epoch 129/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0736 - accuracy: 0.9773 - val_loss: 2.7659 - val_accuracy: 0.6696
# Epoch 130/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0373 - accuracy: 0.9890 - val_loss: 823.5238 - val_accuracy: 0.6386
# Epoch 131/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0475 - accuracy: 0.9849 - val_loss: 2.3191 - val_accuracy: 0.6944
# Epoch 132/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0392 - accuracy: 0.9866 - val_loss: 2.7359 - val_accuracy: 0.6751
# Epoch 133/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.0608 - accuracy: 0.9812 - val_loss: 558.0037 - val_accuracy: 0.6968
# Epoch 134/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0570 - accuracy: 0.9833 - val_loss: 2.9603 - val_accuracy: 0.6813
# Epoch 135/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0452 - accuracy: 0.9878 - val_loss: 2.7124 - val_accuracy: 0.6962
# Epoch 136/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0501 - accuracy: 0.9857 - val_loss: 2.7583 - val_accuracy: 0.6875
# Epoch 137/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0231 - accuracy: 0.9928 - val_loss: 2.6182 - val_accuracy: 0.6826
# Epoch 138/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0478 - accuracy: 0.9870 - val_loss: 2.0927 - val_accuracy: 0.6937
# Epoch 139/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0433 - accuracy: 0.9880 - val_loss: 28.1625 - val_accuracy: 0.6820
# Epoch 140/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.0326 - accuracy: 0.9899 - val_loss: 537.9597 - val_accuracy: 0.6975
# Epoch 141/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0561 - accuracy: 0.9820 - val_loss: 217.5361 - val_accuracy: 0.6944
# Epoch 142/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0077 - accuracy: 0.9986 - val_loss: 2.9567 - val_accuracy: 0.6913
# Epoch 143/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0477 - accuracy: 0.9864 - val_loss: 7.4106 - val_accuracy: 0.6764
# Epoch 144/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.1050 - accuracy: 0.9675 - val_loss: 4.0200 - val_accuracy: 0.6590
# Epoch 145/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0543 - accuracy: 0.9812 - val_loss: 2.4432 - val_accuracy: 0.6968
# Epoch 146/150
# 152/152 [==============================] - 3s 18ms/step - loss: 0.0203 - accuracy: 0.9938 - val_loss: 3.3655 - val_accuracy: 0.6764
# Epoch 147/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0577 - accuracy: 0.9857 - val_loss: 2.5291 - val_accuracy: 0.7037
# Epoch 148/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0308 - accuracy: 0.9909 - val_loss: 2.5841 - val_accuracy: 0.6813
# Epoch 149/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0369 - accuracy: 0.9880 - val_loss: 2.7468 - val_accuracy: 0.6956
# Epoch 150/150
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0479 - accuracy: 0.9853 - val_loss: 3.7932 - val_accuracy: 0.6937
# elapsed time training dataset (sec): 431.4990508556366

# %%
history_dict = hist.history

loss_values = history_dict['loss']
acc_values = history_dict['accuracy']
if split_val:
    val_loss_values = history_dict['val_loss']
    val_acc_values = history_dict['val_accuracy']

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

ax1.plot(loss_values, 'blue', label='Training Loss')
if split_val:
    ax1.plot(val_loss_values, 'orange', label='Validation Loss')
ax1.set_title('Training and validation loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend()

ax2.plot(acc_values, 'blue', label='Training accuracy')
if split_val:
    ax2.plot(val_acc_values, 'orange', label='Validation accuracy')
ax2.set_title('Training and validation accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.legend()

plt.show()

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print('test loss:', loss)
print('test accuracy:', accuracy)
# Out:
# 51/51 [==============================] - 0s 8ms/step - loss: 2.8175 - accuracy: 0.6776
# test loss: 2.8175320625305176
# test accuracy: 0.6776193380355835

# %% [markdown]
# # 파일 테스트

# %%
test_file_name = 'dataset/negative/1001_DFA_ANG_XX.wav'

# %%
prediction_feature = extract_feature(test_file_name, input_shape[0]).reshape((1, ) + input_shape)
model = load_model(model_save_path)

predicted_proba = model.predict(prediction_feature)[0]
predicted_class = np.argmax(predicted_proba)

print('classification result:', le.classes_[predicted_class])
